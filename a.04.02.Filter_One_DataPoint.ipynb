# %% [raw]
# ! pwd

# %%
import os
import pandas as pd
import glob
import geopandas as gpd
import datetime
import numpy as np
import csv
import copy

# %%
raw_trace = pd.read_csv(os.getcwd()+'/2020_Jan_Trace_Filtered/combined_traces.csv')

# %%
grouped_raw_trace = raw_trace.groupby('ANONID')

# %%
grouped_raw_trace_1 = grouped_raw_trace.filter(lambda x: len(x) > 1)

# %%
grouped_raw_trace_1 # rows means the number of gpa data points collected, noted not only for Jan data
# Out:
#            ANONID   TIMESTAMP   LATITUDE  LONGITUDE  HEADING  SPEED  \
# 0         1302247  1581447174  38.836470 -77.091520     64.0   92.0
# 2         1302347  1581447331  38.919974 -77.108360    144.0   98.0
# 3         1302353  1581447338  38.847782 -77.007153      0.0   65.0
# 4         1302361  1581447358  38.866260 -77.131200     88.0   64.0
# 5         1302290  1581447365  38.850100 -77.007600    184.0   74.0
# ...           ...         ...        ...        ...      ...    ...
# 24083413    54206  1578061692  38.884600 -77.064190    154.0   77.0
# 24083414    54248  1578061692  38.916248 -77.056539    224.0    0.0
# 24083415    54026  1578061707  38.915711 -76.980519    215.0    0.0
# 24083416    54065  1578061711  38.901069 -77.038674    248.0    0.0
# 24083417    54229  1578061791  38.853771 -77.043620    345.0   39.6
#
#                      DATETIME       PID  \
# 0         2020-02-11T18:52:54  19184722
# 2         2020-02-11T18:55:31  19185964
# ...

# %%
grouped_raw_trace_1.to_csv(os.getcwd()+'/2020_Jan_Trace_Filtered/1_No_combined_traces.csv', index=False)
